# %%
import pandas as pd

#load dataset
data_xls = pd.read_excel('Training data.xlsx', 'Info', index_col=None)
data_xls.to_csv('Info.csv', encoding='utf-8',index = False)
data_xls = pd.read_excel('Training data.xlsx', 'TPR', index_col=None)
data_xls.to_csv('TPR.csv', encoding='utf-8', index = False)

infoSet = pd.read_csv("Info.csv", header = None, skiprows=[0])
TPRSet = pd.read_csv("TPR.csv", header = None, skiprows=[0])

infoSet
# Out:
#             0  1   2    3                                                  4  \
# 0    12654924  1  62  1,4     Ertapenem Sod,Cefmetazole,Amikacin,Norfloxacin
# 1    13919017  1  86    1                                                  0
# 2    13344466  1  81    4  Piperacillin+Tazobactam,Imipenem+cilastatin,Le...
# 3    13225525  2  89  1,2                                                  0
# 4    12035675  2  71  1,4                               Ceftazidime,Cefixime
# ..        ... ..  ..  ...                                                ...
# 315   3044497  2  39    1                                                  0
# 316   3507318  2  55    1                                         Cephradine
# 317   3406405  1  79    1  Levofloxacin,Ertapenem Sod,Cefazolin,Cephradin...
# 318   3945785  2  77    1                                        Doxycycline
# 319   3692910  2  73    1                               Cefixime,Cefmetazole
#
#                                                      5  6
# 0              Escherichia coli,Pseudomonas aeruginosa  0
# 1                                                    0  1
# 2    Candida albicans,Pseudomonas aeruginosa,Staphy...  0
# 3                                                    0  0
# 4                                 Enterococcus faecium  0
# ..                                                 ... ..
# 315                                                  0  0
# 316                                                  0  0
# 317               Klebsiella pneumoniae ssp pneumoniae  1
# 318                                                  0  0
# 319                                                  0  0
#
# [320 rows x 7 columns]

# %%
# merge 2 set
from sklearn.decomposition import PCA

aggregation_functions = {2: 'mean', 3: 'mean', 4: 'mean', 5: 'mean', 6: 'mean'}

TPRaggreg = TPRSet.groupby(TPRSet[0]).aggregate(aggregation_functions)
label = {"No", "Gender", "Age", "bact", "T", "P", "R", "NBPS", "NBPD"}
label = {0:"No"}
mergeSet = pd.merge(infoSet.iloc[:, [True, True, True, False, False, False, False]], TPRaggreg.iloc[:, [True, True, True, False, False]], on=0)
# mergeSet.rename(columns=label)
# mergeSet = pd.merge(infoSet.iloc[:, [True, True, True, False, False, False, True]], TPRaggreg.iloc[:, [True, True, True, False, False]], on=0)
mergeSet
# Out:
#             0  1  2_x        2_y           3          4
# 0    12654924  1   62  36.547368  111.095238  19.437500
# 1    13919017  1   86  36.356250   96.560000  17.176471
# 2    13344466  1   81  36.645833   71.772727  18.388889
# 3    13225525  2   89  36.940000   85.700000  18.900000
# 4    12035675  2   71  36.636364   93.416667  19.136364
# ..        ... ..  ...        ...         ...        ...
# 315   3044497  2   39  36.800000   83.772727  18.250000
# 316   3507318  2   55  37.137931   96.421053  18.062500
# 317   3406405  1   79  36.655556  118.679245  19.145833
# 318   3945785  2   77  36.941176   74.631579  19.250000
# 319   3692910  2   73  36.580000  111.000000  17.933333
#
# [320 rows x 6 columns]

# %%
import numpy as np

def str_trim(series):
    series = series.replace(' ', np.nan)
    series = series.replace('', np.nan, regex=True)
    series = series.replace("0", np.nan, regex=True)
    
    feature = pd.DataFrame(series.str.split(',').explode())
    feature = feature.drop_duplicates(subset=None, keep='first', inplace=False)
    feature = feature.replace('', np.nan)
    feature = feature.dropna()

    return series, feature

bacteria = infoSet.iloc[:, 5]
bacteria = bacteria.rename("bacteria")
bacteriaSet, bacteria_feature= str_trim(bacteria)

common = infoSet.iloc[:, 3]
common = common.rename("common")
commonSet, commonFeature = str_trim(common)
# commonSet
# bacteria_feature.values()
# mergeSet[5] = bacteriaSet
bacteria_feature = bacteria_feature.to_numpy()
# mergeSet[5]
# Out:
# array([['Escherichia coli'],
#        ['Pseudomonas aeruginosa'],
#        ['Candida albicans'],
#        ['Staphylococcus epidermidis'],
#        ['Enterococcus faecium'],
#        ['Enterobacter cloacae ssp cloacae'],
#        ['Klebsiella pneumoniae ssp pneumoniae'],
#        ['Candida tropicalis'],
#        ['Proteus mirabilis'],
#        ['Staphylococcus pettenkoferi'],
#        ['Staphylococcus capitis'],
#        ['Enterococcus faecium (VRE)'],
#        ['Klebsiella pneumoniae ssp ozaenae'],
#        ['Staphylococcus caprae'],
#        ['Staphylococcus aureus (MRSA)'],
#        ['Providencia stuartii'],
#        ['Citrobacter koseri'],
#        ['Salmonella group D1(non typhi)'],
#        ['Enterococcus faecalis'],
#        ['Yeast-like'],
#        ['Achromobacter denitrificans'],
#        ['Staphylococcus haemolyticus'],
#        ['Corynebacterium striatum'],
#        ['Morganella morganii ssp morganii'],
#        ['Candida glabrata'],
#        ['Pseudomonas putida'],
#        ['Acinetobacter baumannii'],
#        ['Cyberlindnera fabianii'],
#        ['Salmonella group C1'],
#        ['Staphylococcus aureus']], dtype=object)

# %%
def extract_df(ser, features):
    df= pd.DataFrame()
    for feature in features:
        id = 0
        new_list = []
        print(feature)
#         for element in ser:
# #             print(element)
#             if feature == element:
# # #                 print ("{} {}/// {}".format(id, element, feature))
#                 new_list.append(1)
#             else:
#                 new_list.append(0)
# #             id += 1
    
        df[feature] = new_list
    return df
            
#origin_ant
bacteria_df = extract_df(bacteriaSet, bacteria_feature)
common_df = extract_df(commonSet, commonFeature)
common_df
# Out:
# bacteria
# common
# Empty DataFrame
# Columns: [common]
# Index: []

# %%
# # Create one hot encoder
# from sklearn.compose import ColumnTransformer 

# ct = ColumnTransformer([("Name", OneHotEncoder(),[5])], remainder="passthrough")
# mergeSet = ct.fit_transform(mergeSet)
# data = np.array(ct.fit_transform(mergeSet), dtype = np.str) 

# # mergeSet.iloc[:, -3:-1]

# %%
# from sklearn.feature_selection import SelectKBest

# kb = SelectKBest(f_classif, k=15).fit(mergeSet.iloc[:,, Y1)
# X = kb.transform(X1)
# X

# %%
# Extract data
import numpy as np
from sklearn import preprocessing


# 創造 dummy variables
label_encoder = preprocessing.LabelEncoder()
encoded_no = label_encoder.fit_transform(mergeSet[0])

# 建立訓練與測試資料
patient_x = mergeSet.iloc[:, [False, True, True, False, False, True, True, True]]
patient_y = mergeSet[6]

patient_x
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-335-152e47c128cf> in <module>
#       9
#      10 # 建立訓練與測試資料
# ---> 11 patient_x = mergeSet.iloc[:, [False, True, True, False, False, True, True, True]]
#      12 patient_y = mergeSet[6]
#      13
#
# ~/Desktop/homework/dm_pj1/ENV/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# ~/Desktop/homework/dm_pj1/ENV/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1447             pass
#    1448
# -> 1449         return self._getitem_tuple_same_dim(tup)
#    1450
#    1451     def _get_list_axis(self, key, axis: int):
#
# ~/Desktop/homework/dm_pj1/ENV/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_tuple_same_dim(self, tup)
#     748                 continue
#     749
# --> 750             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     751             # We should never have retval.ndim < self.ndim, as that should
#     752             #  be handled by the _getitem_lowerdim call above.
#
# ~/Desktop/homework/dm_pj1/ENV/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1481         if com.is_bool_indexer(key):
#    1482             self._validate_key(key, axis)
# -> 1483             return self._getbool_axis(key, axis=axis)
#    1484
#    1485         # a list of integers
#
# ~/Desktop/homework/dm_pj1/ENV/lib/python3.8/site-packages/pandas/core/indexing.py in _getbool_axis(self, key, axis)
#     894         # caller is responsible for ensuring non-None axis
#     895         labels = self.obj._get_axis(axis)
# --> 896         key = check_bool_indexer(labels, key)
#     897         inds = key.nonzero()[0]
#     898         return self.obj._take_with_is_copy(inds, axis=axis)
#
# ~/Desktop/homework/dm_pj1/ENV/lib/python3.8/site-packages/pandas/core/indexing.py in check_bool_indexer(index, key)
#    2195         # key may contain nan elements, check_array_indexer needs bool array
#    2196         result = pd_array(result, dtype=bool)
# -> 2197     return check_array_indexer(index, result)
#    2198
#    2199
#
# ~/Desktop/homework/dm_pj1/ENV/lib/python3.8/site-packages/pandas/core/indexers.py in check_array_indexer(array, indexer)
#     468         # GH26658
#     469         if len(indexer) != len(array):
# --> 470             raise IndexError(
#     471                 f"Boolean index has wrong length: "
#     472                 f"{len(indexer)} instead of {len(array)}"
#
# IndexError: Boolean index has wrong length: 8 instead of 6

# %%
# Seperate training set and testing set
from sklearn import ensemble, model_selection, metrics
train_X, test_X, train_y, test_y = model_selection.train_test_split(patient_x, patient_y, test_size = 0.3)

# Create random forest model
forest = ensemble.RandomForestClassifier(n_estimators = 100)
forest_fit = forest.fit(train_X, train_y)

# Predict
test_y_predicted = forest.predict(test_X)

# Score
accuracy = metrics.accuracy_score(test_y, test_y_predicted)
print(accuracy)

# %%
# Cal AUC
fpr, tpr, thresholds = metrics.roc_curve(test_y, test_y_predicted)
auc = metrics.auc(fpr, tpr)
print(auc)

# %%
# f1 score
f1 = metrics.f1_score(test_y, test_y_predicted)
f1
